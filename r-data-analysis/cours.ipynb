# %%
D = read.csv("/Users/whz/Desktop/pone.0198597.s005 (1).csv")

# %%
head(D)
# Out:
#   X experiment  insect_type insect_no arrival_week insect_test_no is_long_test
# 1 1 hornet_2012 o2012       13        NA           1              FALSE
# 2 2 hornet_2012 o2012       13        NA           2              FALSE
# 3 3 hornet_2012 o2012       13        NA           3              FALSE
# 4 4 hornet_2012 o2012       13        NA           5              FALSE
# 5 5 hornet_2012 o2012       13        NA           6              FALSE
# 6 6 hornet_2012 o2012       13        NA           7              FALSE
#   test_begin_date test_begin_time test_end_date ⋯ jump_mean_duration
# 1 2012-09-06      10:10:46        2012-09-06    ⋯ 1.645
# 2 2012-09-07      10:56:38        2012-09-07    ⋯ 0.000
# 3 2012-09-10      14:04:48        2012-09-10    ⋯ 0.000
# 4 2012-09-12      10:01:36        2012-09-12    ⋯ 3.997
# 5 2012-09-13      10:08:08        2012-09-13    ⋯ 1.302
# 6 2012-09-14      11:10:13        2012-09-14    ⋯ 2.686
# ...

# %%
summary(D)
# Out:
#        X        experiment        insect_type          insect_no
#  Min.   :  1   Length:997         Length:997         Min.   :  1.00
#  1st Qu.:250   Class :character   Class :character   1st Qu.: 48.00
#  Median :499   Mode  :character   Mode  :character   Median : 75.00
#  Mean   :499                                         Mean   : 85.36
#  3rd Qu.:748                                         3rd Qu.:124.00
#  Max.   :997                                         Max.   :195.00
#
#   arrival_week    insect_test_no   is_long_test    test_begin_date
#  Min.   : 7.180   Min.   : 1.000   Mode :logical   Length:997
#  1st Qu.: 8.290   1st Qu.: 2.000   FALSE:960       Class :character
#  Median : 9.120   Median : 5.000   TRUE :37        Mode  :character
#  Mean   : 8.834   Mean   : 7.631
#  3rd Qu.: 9.260   3rd Qu.:10.000
#  Max.   :10.310   Max.   :41.000
#  NA's   :509
#  test_begin_time    test_end_date      test_end_time      test_duration
# ...

# %%
rcauchy(30)
# Out:
#  [1]   2.41328536  -0.68149472 434.67198035   1.48306180   0.47866097
#  [6]  -0.43550850   0.67301374   0.41731495  -0.72831919   0.17762698
# [11]   0.75782896   0.22682894  -9.54656893  -0.02063821   0.12847779
# [16]  -0.16038188  -4.77853835   0.27084954   1.42080811   1.25914058
# [21]  -0.27806818  -3.30229629   2.04841362  -6.05941454  -1.32755757
# [26]  -0.91456119  -0.83057428   0.10674792  -1.16057886   1.19757325

# %% [markdown]
# ----

# %%
seqva = rnorm(10000)

# %%
plot(cumsum(seqva)/(1:length(seqva)))
# Out:
# plot without title

# %%
seqva2 = rt(10000,df=2)
plot(cumsum(seqva2)/(1:length(seqva)))
# Out:
# plot without title

# %%
seqva3=rcauchy(10000)
plot(cumsum(seqva3)/(1:length(seqva)))
# Out:
# plot without title

# %%
qqnorm(seqva)
qqline(seqva)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
hist(D$flights_duration)
# Out:
# Plot with title “Histogram of D$flights_duration”

# %%
D2013 = D[D$insect_type=="a2013",]
D2013
# Out:
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      X experiment insect_type insect_no arrival_week insect_test_no
#      is_long_test test_begin_date test_begin_time test_end_date ⋯
#      jump_mean_duration jumps_length jump_mean_length jumps_mean_speed nb_rests
#      rests_duration rest_mean_duration insect_before_weight insect_after_weight
#      weight_loss
